# %%
# %matplotlib inline
import sys, os, time
sys.path.append("..")

import numpy as np
import matplotlib.pyplot as plt

import utils

# %%
unmasked_images = utils.get_raw_covidx_images(masked=False)
masked_images = utils.get_raw_covidx_images(masked=True)
masked_equalized_images_transformed = utils.transform_to_equalized(masked_images)

# %%
idx = 0

plt.figure(figsize=(5,5))
plt.imshow(unmasked_images[idx])
plt.axis("off")
plt.show()
plt.close()

plt.figure(figsize=(5,5))
plt.imshow(masked_images[idx])
plt.axis("off")
plt.show()
plt.close()

plt.figure(figsize=(5,5))
plt.imshow(masked_equalized_images_transformed[idx])
plt.axis("off")
plt.show()
plt.close()
